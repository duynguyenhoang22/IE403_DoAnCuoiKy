# %%
# %pip install xgboost scikit-learn pandas joblib matplotlib seaborn requests tldextract beautifulsoup4 ddgs iocextract tdqm
# Out:
# ...
#   Using cached tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached ddgs-9.10.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.1 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 8.8 MB/s  0:00:00
# ...
#   Created wheel for tdqm: filename=tdqm-0.0.1-py3-none-any.whl size=1400 sha256=a3c64b9b9ecb6bf4cbaef06a7697fe00048e456ac199e403a6ac3340844ecef5
#   Stored in directory: c:\users\duyng\appdata\local\pip\cache\wheels\9a\91\f3\44d4e5da089935024002c5351f851f6f96e3ffa76995154241
# ...
