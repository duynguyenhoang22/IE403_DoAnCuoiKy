# %%
# %pip install xgboost scikit-learn pandas joblib matplotlib seaborn requests tldextract duckduckgo-search ddgs iocextract tdqm streamlit
# Out:
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.0 MB 460.7 kB/s eta 0:00:19
#    -- ------------------------------------- 0.5/9.0 MB 460.7 kB/s eta 0:00:19
#    -- ------------------------------------- 0.5/9.0 MB 460.7 kB/s eta 0:00:19
#    --- ------------------------------------ 0.8/9.0 MB 395.8 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.0 MB 395.8 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.0 MB 395.8 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.0/9.0 MB 402.0 kB/s eta 0:00:20
# ...
