# %%
# %pip install xgboost scikit-learn pandas joblib matplotlib seaborn requests tldextract duckduckgo-search ddgs iocextract tdqm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script ddgs.exe is installed in 'c:\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
